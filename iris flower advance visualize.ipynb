# %% [markdown]
# # Iris flower- Advance visualization

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# importing the dataset
iris = pd.read_csv(r"D:\October\13-10-23\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv")

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
len(iris)
# Out:
# 150

# %%
iris.drop('Id', axis=1, inplace=True)  # the Id colunms

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris['Species'].value_counts()  # count the unique values of the arugument
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
# we have the type of iris plant

# %%
sns.countplot(x='Species', data=iris)  # countplot to plot the graph string to flot using count function
plt.show()

# %%
# joinplot
fig = sns.jointplot(data=iris, x='SepalLengthCm',y='SepalWidthCm')

# %%
fig1 = sns.jointplot(data=iris, x='SepalLengthCm',y='SepalWidthCm',kind='hex')

# %%
fig2 = sns.jointplot(data=iris, x='SepalLengthCm',y='SepalWidthCm',kind='reg')

# %%
sns.lmplot(data=iris,x='SepalLengthCm',y='SepalWidthCm',hue='Species', fit_reg=False)

# %%
# %matplotlib inline
# Facetgrid plot    we use the plot like lmplot
fac = sns.FacetGrid(iris,hue='Species',height= 5).map(plt.scatter,'SepalLengthCm','SepalWidthCm').add_legend()

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
figg=plt.gcf()
figg.set_size_inches(8,5) #only this fig size 
figg=sns.boxplot(x='Species',y='PetalLengthCm', data=iris,order=['Iris-virginica','Iris-versicolor','Iris-setosa'],\
                linewidth=2.5,orient='v',dodge=False)

# %%
iris.boxplot(by='Species', figsize=(10,6))  # boxplot grouped by species
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
#strip plot
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.stripplot(x='Species',y='SepalLengthCm',data=iris,jitter=True,edgecolor='gray',size=10,palette='winter',orient='v')

# %%
#combined box and strip plot
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(x='Species',y='SepalLengthCm',data=iris)
fig=sns.stripplot(x='Species',y='SepalLengthCm',data=iris,jitter=True,edgecolor='gray')

# %%
ax= sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
ax= sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")
#set the box plot color
#boxtwo = ax.artists[0]
#boxtwo.set_facecolor('yellow')  
#boxtwo.set_edgecolor('black')

#boxthree=ax.artists[1]
#boxthree.set_facecolor('red')
#boxthree.set_edgecolor('black')

#boxfour=ax.artists[2]
#boxfour.set_facecolor('green')
#boxfour.set_edgecolor('black')

plt.show()

# %%
#violin plot is combination of kdeand box plot
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.violinplot(x='Species',y='SepalLengthCm',data=iris)

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
# Pair plot is compare to each variables
fig= sns.pairplot(iris,kind='scatter')

# %%
sns.pairplot(iris,hue='Species')

# %%
#combined boxplot and stripplot
ax=plt.gcf()
ax.set_size_inches(10,7)

# Define a custom color palette with three colors for each species
custom_palette_boxplot = {"Iris-setosa": "green", "Iris-versicolor": "red", "Iris-virginica": "yellow"}
custom_palette_stripplot= {"Iris-setosa": "blue", "Iris-versicolor": "orange", "Iris-virginica": "green"}

# Create a box plot
ax = sns.boxplot(data=iris, x='Species', y='PetalLengthCm',palette=custom_palette_boxplot)
#Create a Strip plot
ax=sns.stripplot(data=iris,x='Species',y='PetalLengthCm',jitter=True,edgecolor='gray',palette=custom_palette_stripplot)

plt.show()

# %%
iris.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
fig=plt.gcf()
fig.set_size_inches(10,10)
fig= sns.heatmap(iris.corr(), vmin=-1,vmax=1,cmap='cubehelix',annot=True,linewidths=1, linecolor='k', cbar=True,\
               cbar_kws={'orientation':'vertical'},square=True,mask=False)

# %%
fig=plt.gcf()
fig.set_size_inches(12,6)
iris.hist(edgecolor='black',linewidth=1.2)
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
g= sns.swarmplot(x='Species',y='PetalLengthCm',data=iris,hue='Species')  # this plot to help clear data point and avoid overplotting

# %%
sns.set_style('dark')
fig=plt.gcf()
fig.set_size_inches(10,6)
g= sns.swarmplot(x='Species',y='PetalLengthCm',data=iris,color='white',edgecolor='black')
v = sns.violinplot(x='Species',y='PetalLengthCm',data=iris,inner=None)

# %%
sns.lmplot(x='PetalLengthCm',y='PetalWidthCm',data=iris)

# %%
fig= sns.FacetGrid(iris,hue='Species',height=6).map(sns.kdeplot,'PetalLengthCm').add_legend()
plt.ioff()         # disable the interactive mode

# %%
#f,ax= plt.subplot((2,2),figsize=(10,6))
sns.catplot(x='Species',y='PetalLengthCm',data=iris,kind='point') # factorplot instead use catplot use kind point

# %%
sns.__version__
# Out:
# '0.13.0'

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxenplot(x='Species',y='SepalLengthCm',data=iris)

# %%
# kde plot only single cateforical of 2 aruguments
sub=iris[iris['Species']=='Iris-setosa']
sns.kdeplot(data=sub[['SepalLengthCm','SepalWidthCm']], shade=True, shade_lowest=False)
plt.title('Iris-setosa')
plt.xlabel('Sepal Length Cm')
plt.ylabel('Sepal Width Cm')
# Out:
# Text(21.069444444444443, 0.5, 'Sepal Width Cm')

# %%
f,axes= plt.subplots(2,2,figsize=(10,10))

k1=sns.boxplot(data=iris,x='Species',y='PetalLengthCm',ax=axes[0,0])
k2=sns.violinplot(data=iris,x='Species',y='PetalLengthCm',ax=axes[0,1])
k3=sns.stripplot(data=iris,x='Species',y='SepalLengthCm',jitter=True,edgecolor='grey',size=8,palette='winter',orient='v',ax=axes[1,0])
axes[1,1].hist(iris.PetalLengthCm,bins=50)

plt.show()

# %%
iris['Species']= iris['Species'].astype('category')
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    category
# dtypes: category(1), float64(4)
# memory usage: 5.1 KB

# %%
from matplotlib import pyplot as plt 
h= plt.hist([iris[iris.Species =='Iris-setosa'].SepalLengthCm,\
             iris[iris.Species =='Iris-versicolor'].SepalLengthCm,\
             iris[iris.Species =='Iris-virginica'].SepalLengthCm],bins=30,stacked=True,rwidth=1)
plt.show()

# %%
# same output shouing above
list1=list()
mylabels=list()
for gen in iris.Species.cat.categories:
    list1.append(iris[iris.Species==gen].SepalLengthCm)
    mylabels.append(gen)
    
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %%
sns.distplot(iris['PetalLengthCm'],kde=True,bins=10)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %%
iris.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],alpha=0.4,figsize=(10,6))
# Out:
# <Axes: >
